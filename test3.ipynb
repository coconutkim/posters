# %%
# 훈련셋 준비하기

import os
import random
import shutil

def move_random_images(source_folder, destination_folder, num_images):
    # 원본 폴더에서 이미지 파일 목록 가져오기
    image_extensions = ('.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff')
    all_images = [
        f for f in os.listdir(source_folder) 
        if f.lower().endswith(image_extensions) and os.path.isfile(os.path.join(source_folder, f))
    ]
    
    # 선택할 이미지 수가 전체 이미지 수보다 많으면 조정
    # num_images = min(num_images, len(all_images))

    # 무작위로 이미지 선택
    selected_images = random.sample(all_images, num_images)

    # 목적지 폴더가 존재하지 않으면 생성
    os.makedirs(destination_folder, exist_ok=True)

    # 선택된 이미지를 목적지 폴더로 이동
    for image in selected_images:
        src = os.path.join(source_folder, image)
        dst = os.path.join(destination_folder, image)
        shutil.move(src, dst)  # 이동 (복사가 아님)

    print(f"{num_images} images moved to '{destination_folder}'.")

# 경로 설정
folder_path = r'G:\내 드라이브\project_poster\balance_data_rates\#new'
destination_path = r'G:\내 드라이브\project_poster\balance_data_rates\#new_test'

# 함수 호출
move_random_images(folder_path, destination_path, 1750)
# Out:
# 1750 images moved to 'G:\내 드라이브\project_poster\balance_data_rates\#new_test'.

# %%
genre_mapping = {
    "드라마": 1 << 43,
    "첩보": 1 << 42,
    "옴니버스": 1 << 41,
    "뮤직": 1 << 40,
    "동성애": 1 << 39,
    "로드무비": 1 << 38,
    "아동": 1 << 37,
    "하이틴(고교)": 1 << 36,
    "전기": 1 << 35,
    "청춘영화": 1 << 34,
    "재난": 1 << 33,
    "문예": 1 << 32,
    "연쇄극": 1 << 31,
    "신파": 1 << 30,
    "활극": 1 << 29,
    "반공/분단": 1 << 28,
    "군사": 1 << 27,
    "계몽": 1 << 26,
    "사회물(경향)": 1 << 25,
    "스포츠": 1 << 24,
    "합작(번안물)": 1 << 23,
    "종교": 1 << 22,
    "무협": 1 << 21,
    "미스터리": 1 << 20,
    "SF": 1 << 19,
    "코메디": 1 << 18,
    "느와르": 1 << 17,
    "액션": 1 << 16,
    "범죄": 1 << 15,
    "어드벤처": 1 << 14,
    "가족": 1 << 13,
    "에로": 1 << 12,
    "멜로/로맨스": 1 << 11,
    '멜로드라마': 1 << 11,
    "공포": 1 << 10,
    "뮤지컬": 1 << 9,
    "시대극/사극": 1 << 8,
    '실험': 1 << 7,
    '스릴러': 1 << 5,
    '서부': 1 << 4,
    '전쟁': 1 << 3,
    '갱스터': 1 << 2,
    '판타지': 1 << 1,
    '해양액션': 1 << 0
}

resized_genre_mapping = {
    "드라마": ["드라마", "청춘영화", "사회물(경향)",'가족', '하이틴(고교)'],
    "코메디": ["코메디"],
    '로맨스': ['멜로/로맨스', '멜로드라마', '에로','동성애'],
    "액션": ["액션", "재난", "범죄", "느와르",
           '활극','첩보','해양액션', "서부", "갱스터", '무협',
           "전쟁", "군사",'반공/분단'],
    "SF/판타지": ["SF", "판타지", "어드벤처"],
    "공포": ["공포", "스릴러", "미스터리"],
    "기타": ["옴니버스", "종교", "실험",'스포츠', '계몽', '문예', '신파', "뮤지컬",
           "뮤직",'시대극/사극','전기', "아동",'로드무비']
}

# %% [markdown]
# ```python
# genre_mapping = {
#     "드라마": 1 << 43,
#     "첩보": 1 << 42,
#     "옴니버스": 1 << 41,
#     "뮤직": 1 << 40,
#     "동성애": 1 << 39,
#     "로드무비": 1 << 38,
#     "아동": 1 << 37,
#     "하이틴(고교)": 1 << 36,
#     "전기": 1 << 35,
#     "청춘영화": 1 << 34,
#     "재난": 1 << 33,
#     "문예": 1 << 32,
#     "연쇄극": 1 << 31,
#     "신파": 1 << 30,
#     "활극": 1 << 29,
#     "반공/분단": 1 << 28,
#     "군사": 1 << 27,
#     "계몽": 1 << 26,
#     "사회물(경향)": 1 << 25,
#     "스포츠": 1 << 24,
#     "합작(번안물)": 1 << 23,
#     "종교": 1 << 22,
#     "무협": 1 << 21,
#     "미스터리": 1 << 20,
#     "SF": 1 << 19,
#     "코메디": 1 << 18,
#     "느와르": 1 << 17,
#     "액션": 1 << 16,
#     "범죄": 1 << 15,
#     "어드벤처": 1 << 14,
#     "가족": 1 << 13,
#     "에로": 1 << 12,
#     "멜로/로맨스": 1 << 11,
#     '멜로드라마': 1 << 11,
#     "공포": 1 << 10,
#     "뮤지컬": 1 << 9,
#     "시대극/사극": 1 << 8,
#     '실험': 1 << 7,
#     '스릴러': 1 << 5,
#     '서부': 1 << 4,
#     '전쟁': 1 << 3,
#     '갱스터': 1 << 2,
#     '판타지': 1 << 1,
#     '해양액션': 1 << 0
# }
#
# resized_genre_mapping = {
#     "드라마": ["드라마", "청춘영화", "사회물(경향)",'가족', '하이틴(고교)'],
#     "코메디": ["코메디"],
#     '로맨스': ['멜로/로맨스', '멜로드라마', '에로','동성애'],
#     "액션": ["액션", "재난", "범죄", "느와르",
#            '활극','첩보','해양액션', "서부", "갱스터", '무협',
#            "전쟁", "군사",'반공/분단'],
#     "SF/판타지": ["SF", "판타지", "어드벤처"],
#     "공포": ["공포", "스릴러", "미스터리"],
#     "기타": ["옴니버스", "종교", "실험",'스포츠', '계몽', '문예', '신파', "뮤지컬",
#            "뮤직",'시대극/사극','전기', "아동",'로드무비']
# }

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# 장르 매핑 정의
genre_mapping = {
    "드라마": 1 << 43,
    "첩보": 1 << 42,
    "옴니버스": 1 << 41,
    "뮤직": 1 << 40,
    "동성애": 1 << 39,
    "로드무비": 1 << 38,
    "아동": 1 << 37,
    "하이틴(고교)": 1 << 36,
    "전기": 1 << 35,
    "청춘영화": 1 << 34,
    "재난": 1 << 33,
    "문예": 1 << 32,
    "연쇄극": 1 << 31,
    "신파": 1 << 30,
    "활극": 1 << 29,
    "반공/분단": 1 << 28,
    "군사": 1 << 27,
    "계몽": 1 << 26,
    "사회물(경향)": 1 << 25,
    "스포츠": 1 << 24,
    "합작(번안물)": 1 << 23,
    "종교": 1 << 22,
    "무협": 1 << 21,
    "미스터리": 1 << 20,
    "SF": 1 << 19,
    "코메디": 1 << 18,
    "느와르": 1 << 17,
    "액션": 1 << 16,
    "범죄": 1 << 15,
    "어드벤처": 1 << 14,
    "가족": 1 << 13,
    "에로": 1 << 12,
    "멜로/로맨스": 1 << 11,
    "멜로드라마": 1 << 11,
    "공포": 1 << 10,
    "뮤지컬": 1 << 9,
    "시대극/사극": 1 << 8,
    "실험": 1 << 7,
    "스릴러": 1 << 5,
    "서부": 1 << 4,
    "전쟁": 1 << 3,
    "갱스터": 1 << 2,
    "판타지": 1 << 1,
    "해양액션": 1 << 0
}

resized_genre_mapping = {
    "드라마": ["드라마", "청춘영화", "사회물(경향)", '가족', '하이틴(고교)'],
    "코메디": ["코메디"],
    '로맨스': ['멜로/로맨스', '멜로드라마', '에로', '동성애'],
    "액션": ["액션", "재난", "범죄", "느와르", '활극', '첩보', '해양액션', "서부", "갱스터", '무협', "전쟁", "군사", '반공/분단'],
    "SF/판타지": ["SF", "판타지", "어드벤처"],
    "공포": ["공포", "스릴러", "미스터리"],
    "기타": ["옴니버스", "종교", "실험", '스포츠', '계몽', '문예', '신파', "뮤지컬", "뮤직", '시대극/사극', '전기', "아동", '로드무비']
}

# 이미지 파일 경로
image_file_path = r'C:\ex\posters\test_pics\30일_262144.jpg'

def load_and_preprocess_image(image_path, target_size=(200, 300)):
    # 이미지 열기
    img = Image.open(image_path)
    
    # RGBA 또는 CMYK 모드일 경우 RGB로 변환
    if img.mode in ['RGBA', 'CMYK']:
        img = img.convert('RGB')
    
    # 이미지 리사이즈
    img_resized = img.resize(target_size)
    img_data = np.array(img_resized) / 255.0  # 정규화
    return img_data

def get_genre_from_filename(filename):
    # 파일 이름을 '_'와 '.'으로 나누어 장르 정보 추출
    base_name = os.path.basename(filename)  # 파일 이름만 가져오기
    genre_part = base_name.split('_')[1]  # '_'로 나누고 인덱스 1 가져오기
    return genre_part.split('.')[0]  # '.'로 나누고 인덱스 0 가져오기

def get_resized_genre_list(genre):
    # 주어진 장르를 기반으로 매핑된 장르 반환
    for main_genre, sub_genres in resized_genre_mapping.items():
        if genre in sub_genres:
            return main_genre, sub_genres  # 최종 장르와 하위 장르 반환
    return "기타", []

# 이미지 데이터 로드 및 전처리
image_data = load_and_preprocess_image(image_file_path)

# 파일 이름으로부터 장르 추출
extracted_genre = get_genre_from_filename(image_file_path)

# 최종 장르 매핑
final_genre, sub_genres = get_resized_genre_list(extracted_genre)

print(f"Extracted Genre: {extracted_genre}")
print(f"Resized Genre: {final_genre}")
print(f"Sub-genres: {sub_genres}")

# 이미지 출력
plt.imshow(image_data)
plt.axis('off')  # 축 숨기기
plt.title(f"Extracted Genre: {extracted_genre}")
plt.show()
# Out:
# Extracted Genre: 262144
# Resized Genre: 기타
# Sub-genres: []
